# %% [markdown]
# # **Machine Translation dengan PyTorch**

# %% [markdown]
# ## 1. Install library yang dibutuhkan di Kaggle Notebook

# %%
# !pip install torch torchvision torchaudio
# !pip install torchtext
# !pip install spacy
# !pip install sacrebleu
# !python -m spacy download en_core_web_sm
# !python -m spacy download id_core_web_sm
# !pip install --upgrade --force-reinstall scikit-learn numpy pandas
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (0.21.0+cu124)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.5.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision) (2.3.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision) (11.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: torchtext in /usr/local/lib/python3.11/dist-packages (0.18.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from torchtext) (4.67.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from torchtext) (2.32.4)
# Requirement already satisfied: torch>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from torchtext) (2.6.0+cu124)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchtext) (2.3.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->torchtext) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->torchtext) (4.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->torchtext) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->torchtext) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->torchtext) (2025.5.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->torchtext) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->torchtext) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->torchtext) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->torchtext) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->torchtext) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->torchtext) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->torchtext) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->torchtext) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->torchtext) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->torchtext) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->torchtext) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->torchtext) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->torchtext) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->torchtext) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->torchtext) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.3.0->torchtext) (1.3.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->torchtext) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->torchtext) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->torchtext) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->torchtext) (2025.6.15)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.3.0->torchtext) (3.0.2)
# Requirement already satisfied: spacy in /usr/local/lib/python3.11/dist-packages (3.8.7)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (1.0.13)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.0.10)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /usr/local/lib/python3.11/dist-packages (from spacy) (8.3.6)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.11/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (0.16.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.3.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.32.4)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.11.7)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from spacy) (75.2.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (25.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.5.0)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.11/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.14.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2025.6.15)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.3.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (14.0.0)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.21.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->spacy) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.19.2)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.17.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Requirement already satisfied: sacrebleu in /usr/local/lib/python3.11/dist-packages (2.5.1)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.11/dist-packages (from sacrebleu) (3.2.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.11/dist-packages (from sacrebleu) (2024.11.6)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.11/dist-packages (from sacrebleu) (0.9.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from sacrebleu) (2.3.2)
# Requirement already satisfied: colorama in /usr/local/lib/python3.11/dist-packages (from sacrebleu) (0.4.6)
# Requirement already satisfied: lxml in /usr/local/lib/python3.11/dist-packages (from sacrebleu) (5.4.0)
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 53.7 MB/s eta 0:00:0000:010:01
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
#
# ✘ No compatible package found for 'id_core_web_sm' (spaCy v3.8.7)
#
# Collecting scikit-learn
#   Using cached scikit_learn-1.7.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (11 kB)
# Collecting numpy
#   Using cached numpy-2.3.2-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
# Collecting pandas
#   Using cached pandas-2.3.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (91 kB)
# Collecting scipy>=1.8.0 (from scikit-learn)
#   Using cached scipy-1.16.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (61 kB)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Using cached joblib-1.5.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting python-dateutil>=2.8.2 (from pandas)
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting six>=1.5 (from python-dateutil>=2.8.2->pandas)
#   Using cached six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Using cached scikit_learn-1.7.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (9.7 MB)
# Using cached numpy-2.3.2-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.9 MB)
# Using cached pandas-2.3.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.4 MB)
# Using cached joblib-1.5.1-py3-none-any.whl (307 kB)
# Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached scipy-1.16.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (35.4 MB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Using cached six-1.17.0-py2.py3-none-any.whl (11 kB)
# Installing collected packages: pytz, tzdata, threadpoolctl, six, numpy, joblib, scipy, python-dateutil, scikit-learn, pandas
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2025.2
#     Uninstalling pytz-2025.2:
#       Successfully uninstalled pytz-2025.2
#   Attempting uninstall: tzdata
#     Found existing installation: tzdata 2025.2
#     Uninstalling tzdata-2025.2:
#       Successfully uninstalled tzdata-2025.2
#   Attempting uninstall: threadpoolctl
#     Found existing installation: threadpoolctl 3.6.0
#     Uninstalling threadpoolctl-3.6.0:
#       Successfully uninstalled threadpoolctl-3.6.0
#   Attempting uninstall: six
#     Found existing installation: six 1.17.0
#     Uninstalling six-1.17.0:
#       Successfully uninstalled six-1.17.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.3.2
#     Uninstalling numpy-2.3.2:
#       Successfully uninstalled numpy-2.3.2
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.5.1
#     Uninstalling joblib-1.5.1:
#       Successfully uninstalled joblib-1.5.1
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.16.1
#     Uninstalling scipy-1.16.1:
#       Successfully uninstalled scipy-1.16.1
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.9.0.post0
#     Uninstalling python-dateutil-2.9.0.post0:
#       Successfully uninstalled python-dateutil-2.9.0.post0
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.7.1
#     Uninstalling scikit-learn-1.7.1:
#       Successfully uninstalled scikit-learn-1.7.1
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.3.2
#     Uninstalling pandas-2.3.2:
#       Successfully uninstalled pandas-2.3.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.8.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# gensim 4.3.3 requires numpy<2.0,>=1.18.5, but you have numpy 2.3.2 which is incompatible.
# gensim 4.3.3 requires scipy<1.14.0,>=1.7.0, but you have scipy 1.16.1 which is incompatible.
# mkl-umath 0.1.1 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.3.2 which is incompatible.
# mkl-random 1.2.4 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.3.2 which is incompatible.
# mkl-fft 1.3.8 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.3.2 which is incompatible.
# cupy-cuda12x 13.4.1 requires numpy<2.3,>=1.22, but you have numpy 2.3.2 which is incompatible.
# dask-cudf-cu12 25.2.2 requires pandas<2.2.4dev0,>=2.0, but you have pandas 2.3.2 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.3.2 which is incompatible.
# cudf-cu12 25.2.2 requires pandas<2.2.4dev0,>=2.0, but you have pandas 2.3.2 which is incompatible.
# datasets 3.6.0 requires fsspec[http]<=2025.3.0,>=2023.1.0, but you have fsspec 2025.5.1 which is incompatible.
# ydata-profiling 4.16.1 requires numpy<2.2,>=1.16.0, but you have numpy 2.3.2 which is incompatible.
# ydata-profiling 4.16.1 requires scipy<1.16,>=1.4.1, but you have scipy 1.16.1 which is incompatible.
# onnx 1.18.0 requires protobuf>=4.25.1, but you have protobuf 3.20.3 which is incompatible.
# category-encoders 2.7.0 requires scikit-learn<1.6.0,>=1.0.0, but you have scikit-learn 1.7.1 which is incompatible.
# preprocessing 0.1.13 requires nltk==3.2.4, but you have nltk 3.9.1 which is incompatible.
# google-colab 1.0.0 requires google-auth==2.38.0, but you have google-auth 2.40.3 which is incompatible.
# google-colab 1.0.0 requires notebook==6.5.7, but you have notebook 6.5.4 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.3.2 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.3, but you have requests 2.32.4 which is incompatible.
# google-colab 1.0.0 requires tornado==6.4.2, but you have tornado 6.5.1 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.0 which is incompatible.
# sklearn-compat 0.1.3 requires scikit-learn<1.7,>=1.2, but you have scikit-learn 1.7.1 which is incompatible.
# pandas-gbq 0.29.1 requires google-api-core<3.0.0,>=2.10.2, but you have google-api-core 1.34.1 which is incompatible.
# ibis-framework 9.5.0 requires toolz<1,>=0.11, but you have toolz 1.0.0 which is incompatible.
# plotnine 0.14.5 requires matplotlib>=3.8.0, but you have matplotlib 3.7.2 which is incompatible.
# tensorflow 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 2.3.2 which is incompatible.
# bigframes 2.8.0 requires google-cloud-bigquery[bqstorage,pandas]>=3.31.0, but you have google-cloud-bigquery 3.25.0 which is incompatible.
# bigframes 2.8.0 requires rich<14,>=12.4.4, but you have rich 14.0.0 which is incompatible.
# jupyter-kernel-gateway 2.5.2 requires jupyter-client<8.0,>=5.2.0, but you have jupyter-client 8.6.3 which is incompatible.
# Successfully installed joblib-1.5.1 numpy-2.3.2 pandas-2.3.2 python-dateutil-2.9.0.post0 pytz-2025.2 scikit-learn-1.7.1 scipy-1.16.1 six-1.17.0 threadpoolctl-3.6.0 tzdata-2025.2

# %% [markdown]
# ## 2. Persiapan Data (Preprocessing)
# Langkah ini sangat krusial. Dataset dari ManyThings.org biasanya berupa file teks dengan pasangan kalimat per baris.
#
# ### A. Memuat dan Membersihkan Data
# Dataset yang Anda unduh mungkin memiliki beberapa baris yang tidak relevan (misalnya, baris yang berisi informasi hak cipta). Anda perlu menghapusnya.

# %%
import pandas as pd

data_path = "/kaggle/input/eng-ind-dataset/ind.txt"

# Baca file secara manual
lines = open(data_path, "r", encoding="utf-8").read().splitlines()

eng, indo = [], []
for line in lines:
    parts = line.split("\t")
    if len(parts) >= 2:
        eng.append(parts[0])
        indo.append(parts[1])

df = pd.DataFrame({"eng": eng, "id": indo})
print(df.head())
# Out:
#     eng      id
# 0   Hi.    Hai.
# 1  Run!   Lari!
# 2  Run.   Lari!
# 3  Who?  Siapa?
# 4  Wow!    Wow!

# %% [markdown]
# ### B. Tokenisasi
# Tokenisasi adalah proses memecah kalimat menjadi unit-unit yang lebih kecil (token). Untuk tokenisasi subword, Anda bisa menggunakan library seperti SentencePiece atau Hugging Face Tokenizers. Metode ini sangat efektif untuk menangani kata-kata yang tidak dikenal (Out-of-Vocabulary / OOV).

# %%
# Contoh menggunakan SentencePiece (Anda perlu menginstalnya terlebih dahulu)
# !pip install sentencepiece

import sentencepiece as spm

# Gabungkan semua data menjadi satu file untuk melatih tokenizer
df['text'] = df['eng'] + ' ' + df['id']
with open('corpus.txt', 'w', encoding='utf-8') as f:
    f.write('\n'.join(df['text'].tolist()))

# Melatih model SentencePiece
spm.SentencePieceTrainer.train(
    '--input=corpus.txt --model_prefix=spm_bpe --vocab_size=8000 --model_type=bpe')

# Muat model tokenizer yang sudah dilatih
sp = spm.SentencePieceProcessor(model_file='spm_bpe.model')

# Contoh tokenisasi
sentence = "Saya suka belajar Machine Learning."
tokens = sp.encode_as_pieces(sentence)
print(tokens) # Output: [' Saya', ' suka', ' belajar', ' Machine', ' Learning', '.']

# Simpan vocab untuk digunakan nanti
vocab = {sp.id_to_piece(i): i for i in range(sp.get_piece_size())}
print(f"Ukuran vocab: {len(vocab)}")
# Out:
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.11/dist-packages (0.2.0)
# ['▁Saya', '▁suka', '▁belajar', '▁M', 'ach', 'ine', '▁Lear', 'ning', '.']
# Ukuran vocab: 8000
# sentencepiece_trainer.cc(178) LOG(INFO) Running command: --input=corpus.txt --model_prefix=spm_bpe --vocab_size=8000 --model_type=bpe
# sentencepiece_trainer.cc(78) LOG(INFO) Starts training with :
# trainer_spec {
#   input: corpus.txt
#   input_format:
#   model_prefix: spm_bpe
#   model_type: BPE
#   vocab_size: 8000
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   seed_sentencepieces_file:
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 0
#   bos_id: 1
#   eos_id: 2
#   pad_id: -1
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
#   enable_differential_privacy: 0
#   differential_privacy_noise_level: 0
#   differential_privacy_clipping_threshold: 0
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(353) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(185) LOG(INFO) Loading corpus: corpus.txt
# trainer_interface.cc(409) LOG(INFO) Loaded all 14881 sentences
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: <s>
# trainer_interface.cc(425) LOG(INFO) Adding meta_piece: </s>
# trainer_interface.cc(430) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(539) LOG(INFO) all chars count=921408
# trainer_interface.cc(550) LOG(INFO) Done: 99.9513% characters are covered.
# trainer_interface.cc(560) LOG(INFO) Alphabet size=59
# trainer_interface.cc(561) LOG(INFO) Final character coverage=0.999513
# trainer_interface.cc(592) LOG(INFO) Done! preprocessed 14881 sentences.
# trainer_interface.cc(598) LOG(INFO) Tokenizing input sentences with whitespace: 14881
# trainer_interface.cc(609) LOG(INFO) Done! 18024
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=20679 min_freq=1
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5604 size=20 all=1567 active=1507 piece=ang
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3627 size=40 all=2564 active=2504 piece=ku
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=2159 size=60 all=3405 active=3345 piece=us
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1535 size=80 all=4164 active=4104 piece=ur
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=1164 size=100 all=4984 active=4924 piece=um
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=1140 min_freq=79
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=968 size=120 all=5961 active=1893 piece=▁e
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=774 size=140 all=6396 active=2328 piece=▁akan
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=665 size=160 all=6851 active=2783 piece=▁for
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=587 size=180 all=7240 active=3172 piece=ain
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=526 size=200 all=7649 active=3581 piece=▁kn
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=525 min_freq=71
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=487 size=220 all=7991 active=1337 piece=her
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=449 size=240 all=8236 active=1582 piece=ali
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=405 size=260 all=8604 active=1950 piece=alam
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=360 size=280 all=8863 active=2209 piece=ai
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=334 size=300 all=9227 active=2573 piece=▁has
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=332 min_freq=63
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=309 size=320 all=9505 active=1277 piece=▁punya
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=279 size=340 all=9720 active=1492 piece=ind
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=252 size=360 all=10055 active=1827 piece=uc
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=231 size=380 all=10290 active=2062 piece=av
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=215 size=400 all=10601 active=2373 piece=▁pernah
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=214 min_freq=56
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=204 size=420 all=10880 active=1280 piece=▁R
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=193 size=440 all=11184 active=1584 piece=lease
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=179 size=460 all=11423 active=1823 piece=asi
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=175 size=480 all=11601 active=2001 piece=ikir
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=166 size=500 all=11854 active=2254 piece=atang
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=165 min_freq=49
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=159 size=520 all=12045 active=1183 piece=▁work
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=151 size=540 all=12253 active=1391 piece=alan
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=144 size=560 all=12412 active=1550 piece=▁mus
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=140 size=580 all=12595 active=1733 piece=▁pad
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=135 size=600 all=12797 active=1935 piece=ather
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=135 min_freq=44
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=130 size=620 all=12930 active=1127 piece=▁sebuah
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=125 size=640 all=13091 active=1288 piece=▁won
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=120 size=660 all=13220 active=1417 piece=▁anything
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=116 size=680 all=13374 active=1571 piece=▁friend
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=112 size=700 all=13515 active=1712 piece=akit
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=112 min_freq=40
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=108 size=720 all=13707 active=1180 piece=oney
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=105 size=740 all=13868 active=1341 piece=▁Have
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=102 size=760 all=13969 active=1442 piece=▁would
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=99 size=780 all=14154 active=1627 piece=▁Sem
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=96 size=800 all=14243 active=1716 piece=▁French
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=96 min_freq=36
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=93 size=820 all=14298 active=1056 piece=▁gu
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=90 size=840 all=14437 active=1195 piece=ft
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=88 size=860 all=14579 active=1337 piece=ampai
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=85 size=880 all=14677 active=1435 piece=lem
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=84 size=900 all=14741 active=1499 piece=▁merasa
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=84 min_freq=33
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=82 size=920 all=14771 active=1031 piece=▁again
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=80 size=940 all=14846 active=1106 piece=▁mengg
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=77 size=960 all=14973 active=1233 piece=▁besar
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=74 size=980 all=15096 active=1356 piece=enal
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=71 size=1000 all=15228 active=1488 piece=akai
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=71 min_freq=30
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=70 size=1020 all=15334 active=1101 piece=▁keh
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=68 size=1040 all=15401 active=1168 piece=unj
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=66 size=1060 all=15510 active=1277 piece=orm
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=65 size=1080 all=15625 active=1392 piece=▁next
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=63 size=1100 all=15751 active=1518 piece=ious
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=63 min_freq=28
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=62 size=1120 all=15818 active=1059 piece=▁Your
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=61 size=1140 all=15856 active=1097 piece=itar
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=60 size=1160 all=15961 active=1202 piece=▁sus
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=59 size=1180 all=16020 active=1261 piece=arusnya
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=58 size=1200 all=16095 active=1336 piece=▁katakan
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=57 min_freq=26
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=56 size=1220 all=16188 active=1094 piece=iver
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=55 size=1240 all=16312 active=1218 piece=ober
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=54 size=1260 all=16347 active=1253 piece=▁bersama
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=52 size=1280 all=16422 active=1328 piece=obody
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=51 size=1300 all=16517 active=1423 piece=▁masuk
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=51 min_freq=24
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=50 size=1320 all=16595 active=1078 piece=▁afraid
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=49 size=1340 all=16664 active=1147 piece=anjang
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=48 size=1360 all=16730 active=1213 piece=▁menyel
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=47 size=1380 all=16818 active=1301 piece=asanya
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=46 size=1400 all=16870 active=1353 piece=▁harap
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=46 min_freq=22
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=45 size=1420 all=16921 active=1052 piece=▁them
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=44 size=1440 all=16950 active=1081 piece=▁peremp
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=43 size=1460 all=17054 active=1185 piece=▁tried
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=42 size=1480 all=17122 active=1253 piece=▁pay
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=42 size=1500 all=17134 active=1265 piece=▁pekerjaan
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=42 min_freq=21
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=41 size=1520 all=17150 active=1017 piece=▁novel
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=40 size=1540 all=17240 active=1107 piece=▁wife
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=39 size=1560 all=17261 active=1128 piece=unch
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=39 size=1580 all=17292 active=1159 piece=▁without
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=38 size=1600 all=17360 active=1227 piece=▁table
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=38 min_freq=20
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=37 size=1620 all=17485 active=1125 piece=▁ind
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=37 size=1640 all=17521 active=1161 piece=▁meeting
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=36 size=1660 all=17603 active=1243 piece=▁hear
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=35 size=1680 all=17666 active=1306 piece=orry
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=35 size=1700 all=17707 active=1347 piece=▁menikah
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=35 min_freq=19
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=34 size=1720 all=17771 active=1063 piece=▁siap
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=33 size=1740 all=17781 active=1073 piece=oor
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=33 size=1760 all=17857 active=1149 piece=▁jawab
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=32 size=1780 all=17868 active=1160 piece=▁Ad
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=32 size=1800 all=17935 active=1227 piece=▁piano
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=32 min_freq=18
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=31 size=1820 all=17999 active=1065 piece=▁die
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=31 size=1840 all=18027 active=1093 piece=▁almost
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=30 size=1860 all=18044 active=1110 piece=mas
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=30 size=1880 all=18128 active=1194 piece=▁adik
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=30 size=1900 all=18133 active=1199 piece=▁Japanese
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=30 min_freq=17
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=29 size=1920 all=18196 active=1064 piece=ident
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=29 size=1940 all=18226 active=1094 piece=▁jangan
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=28 size=1960 all=18289 active=1157 piece=▁emp
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=28 size=1980 all=18327 active=1195 piece=▁hours
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=28 size=2000 all=18324 active=1192 piece=▁kesalahan
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=28 min_freq=16
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=27 size=2020 all=18409 active=1086 piece=▁eas
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=27 size=2040 all=18410 active=1087 piece=▁menerima
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=26 size=2060 all=18503 active=1180 piece=▁kun
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=26 size=2080 all=18541 active=1218 piece=▁tenis
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=26 size=2100 all=18541 active=1218 piece=▁sebenarnya
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=25 min_freq=15
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=25 size=2120 all=18608 active=1068 piece=adang
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=25 size=2140 all=18617 active=1077 piece=▁bicara
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=25 size=2160 all=18625 active=1085 piece=▁menghabiskan
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=24 size=2180 all=18692 active=1152 piece=ently
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=24 size=2200 all=18706 active=1166 piece=▁those
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=24 min_freq=14
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=24 size=2220 all=18699 active=994 piece=▁expensive
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=23 size=2240 all=18808 active=1103 piece=uruh
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=23 size=2260 all=18854 active=1149 piece=▁prom
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=23 size=2280 all=18866 active=1161 piece=▁accident
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=22 size=2300 all=18924 active=1219 piece=epas
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=22 min_freq=14
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=22 size=2320 all=18994 active=1067 piece=▁mand
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=22 size=2340 all=19019 active=1092 piece=▁Kucing
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=21 size=2360 all=19053 active=1126 piece=olf
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=21 size=2380 all=19137 active=1210 piece=▁Kur
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=21 size=2400 all=19173 active=1246 piece=▁pria
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=21 min_freq=13
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=21 size=2420 all=19181 active=1009 piece=▁crying
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=21 size=2440 all=19171 active=999 piece=▁menjawab
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=20 size=2460 all=19234 active=1062 piece=▁201
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=20 size=2480 all=19284 active=1112 piece=▁Tell
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=20 size=2500 all=19288 active=1116 piece=eberang
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=20 min_freq=12
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=20 size=2520 all=19288 active=999 piece=▁mistake
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=19 size=2540 all=19331 active=1042 piece=cuse
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=19 size=2560 all=19388 active=1099 piece=angku
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=19 size=2580 all=19422 active=1133 piece=asakan
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=19 size=2600 all=19434 active=1145 piece=▁sepatu
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=19 min_freq=12
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=18 size=2620 all=19425 active=992 piece=za
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=18 size=2640 all=19517 active=1084 piece=ries
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=18 size=2660 all=19559 active=1126 piece=embak
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=18 size=2680 all=19612 active=1179 piece=ention
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=18 size=2700 all=19606 active=1173 piece=▁guilty
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=18 min_freq=11
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=18 size=2720 all=19599 active=994 piece=▁dilakukan
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=17 size=2740 all=19667 active=1062 piece=cewa
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=17 size=2760 all=19709 active=1104 piece=alkan
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=17 size=2780 all=19744 active=1139 piece=▁roti
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=17 size=2800 all=19746 active=1141 piece=▁warna
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=17 min_freq=11
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=17 size=2820 all=19747 active=1002 piece=▁menurun
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=17 size=2840 all=19741 active=996 piece=▁Sebaiknya
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=16 size=2860 all=19772 active=1027 piece=▁pi
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=16 size=2880 all=19830 active=1085 piece=▁dij
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=16 size=2900 all=19867 active=1122 piece=▁cons
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=16 min_freq=10
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=16 size=2920 all=19893 active=1019 piece=▁pizza
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=16 size=2940 all=19889 active=1015 piece=ingungan
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=16 size=2960 all=19878 active=1004 piece=▁boyfriend
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=15 size=2980 all=19934 active=1060 piece=▁Ma
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=15 size=3000 all=19998 active=1124 piece=▁bay
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=15 min_freq=10
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=15 size=3020 all=20017 active=1017 piece=▁Pint
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=15 size=3040 all=20038 active=1038 piece=sihkan
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=15 size=3060 all=20046 active=1046 piece=▁shirt
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=15 size=3080 all=20045 active=1045 piece=▁stayed
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=15 size=3100 all=20028 active=1028 piece=▁hospital
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=15 min_freq=10
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=14 size=3120 all=20064 active=1038 piece=net
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=14 size=3140 all=20134 active=1108 piece=urus
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=14 size=3160 all=20191 active=1165 piece=▁Tadi
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=14 size=3180 all=20193 active=1167 piece=▁taxi
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=14 size=3200 all=20209 active=1183 piece=▁darah
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=14 min_freq=9
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=14 size=3220 all=20212 active=1013 piece=▁alasan
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=14 size=3240 all=20203 active=1004 piece=▁explain
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=14 size=3260 all=20195 active=996 piece=▁merindukan
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=13 size=3280 all=20261 active=1062 piece=edit
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=13 size=3300 all=20306 active=1107 piece=▁rid
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=13 min_freq=9
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=13 size=3320 all=20335 active=1042 piece=▁dogs
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=13 size=3340 all=20336 active=1043 piece=ukisan
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=13 size=3360 all=20335 active=1042 piece=▁proud
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=13 size=3380 all=20326 active=1033 piece=▁locked
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=13 size=3400 all=20330 active=1037 piece=▁feeling
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=13 min_freq=8
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=13 size=3420 all=20326 active=1013 piece=▁berharap
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=12 size=3440 all=20345 active=1032 piece=▁z
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=12 size=3460 all=20404 active=1091 piece=▁ob
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=12 size=3480 all=20452 active=1139 piece=▁bin
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=12 size=3500 all=20502 active=1189 piece=▁bowl
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=12 min_freq=8
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=12 size=3520 all=20516 active=1039 piece=irahat
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=12 size=3540 all=20517 active=1040 piece=▁hewan
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=12 size=3560 all=20524 active=1047 piece=▁Sampai
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=12 size=3580 all=20520 active=1043 piece=▁history
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=12 size=3600 all=20511 active=1034 piece=▁waktunya
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=12 min_freq=8
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11 size=3620 all=20496 active=1011 piece=hi
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11 size=3640 all=20572 active=1087 piece=▁po
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11 size=3660 all=20640 active=1155 piece=▁Seh
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11 size=3680 all=20679 active=1194 piece=ambah
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11 size=3700 all=20728 active=1243 piece=▁cond
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=11 min_freq=8
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11 size=3720 all=20742 active=1047 piece=▁umur
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11 size=3740 all=20771 active=1076 piece=▁gagal
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11 size=3760 all=20766 active=1071 piece=▁dariku
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11 size=3780 all=20759 active=1064 piece=▁discuss
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=11 size=3800 all=20754 active=1059 piece=▁promised
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=11 min_freq=7
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=3820 all=20737 active=1021 piece=ech
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=3840 all=20799 active=1083 piece=gest
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=3860 all=20845 active=1129 piece=▁jas
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=3880 all=20893 active=1177 piece=veral
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=3900 all=20902 active=1186 piece=▁side
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=10 min_freq=7
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=3920 all=20904 active=1048 piece=▁known
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=3940 all=20909 active=1053 piece=kusikan
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=3960 all=20919 active=1063 piece=▁missed
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=3980 all=20908 active=1052 piece=▁melalui
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=4000 all=20898 active=1042 piece=▁followed
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=10 min_freq=7
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=10 size=4020 all=20883 active=1030 piece=▁sometimes
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=4040 all=20906 active=1053 piece=iat
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=4060 all=20957 active=1104 piece=anas
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=4080 all=21002 active=1149 piece=ukum
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=4100 all=21040 active=1187 piece=▁sab
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=9 min_freq=7
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=4120 all=21084 active=1093 piece=sibil
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=4140 all=21082 active=1091 piece=▁grap
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=4160 all=21093 active=1102 piece=engkar
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=4180 all=21100 active=1109 piece=▁fruit
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=4200 all=21087 active=1096 piece=artment
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=9 min_freq=6
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=4220 all=21088 active=1054 piece=▁dimana
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=4240 all=21077 active=1043 piece=▁violin
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=4260 all=21065 active=1031 piece=▁learned
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=4280 all=21053 active=1019 piece=▁seharian
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=9 size=4300 all=21035 active=1001 piece=▁watermelon
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=9 min_freq=6
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=4320 all=21041 active=1058 piece=adw
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=4340 all=21098 active=1115 piece=▁mi
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=4360 all=21147 active=1164 piece=kali
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=4380 all=21195 active=1212 piece=▁Nat
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=4400 all=21228 active=1245 piece=▁sea
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=8 min_freq=6
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=4420 all=21257 active=1091 piece=umkan
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=4440 all=21259 active=1093 piece=▁fill
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=4460 all=21259 active=1093 piece=▁size
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=4480 all=21265 active=1099 piece=▁balik
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=4500 all=21249 active=1083 piece=▁motor
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=8 min_freq=6
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=4520 all=21252 active=1065 piece=etakkan
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=4540 all=21241 active=1054 piece=▁common
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=4560 all=21232 active=1045 piece=▁mening
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=4580 all=21229 active=1042 piece=▁twenty
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=4600 all=21225 active=1038 piece=▁factory
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=8 min_freq=6
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=4620 all=21212 active=1049 piece=▁suicide
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=4640 all=21197 active=1034 piece=▁kacamata
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=4660 all=21184 active=1021 piece=▁astronomy
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=8 size=4680 all=21169 active=1006 piece=▁menyalahkan
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=4700 all=21202 active=1039 piece=dle
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=7 min_freq=5
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=4720 all=21254 active=1111 piece=▁ed
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=4740 all=21293 active=1150 piece=ened
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=4760 all=21324 active=1181 piece=urch
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=4780 all=21353 active=1210 piece=▁ham
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=4800 all=21377 active=1234 piece=entuh
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=7 min_freq=5
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=4820 all=21395 active=1084 piece=▁Milk
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=4840 all=21390 active=1079 piece=▁haus
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=4860 all=21396 active=1085 piece=▁shar
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=4880 all=21416 active=1105 piece=▁Cukai
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=4900 all=21417 active=1106 piece=▁elect
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=7 min_freq=5
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=4920 all=21421 active=1072 piece=▁pract
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=4940 all=21418 active=1069 piece=intaimu
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=4960 all=21407 active=1058 piece=▁bohong
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=4980 all=21394 active=1045 piece=▁murder
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=5000 all=21386 active=1037 piece=▁weight
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=7 min_freq=5
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=5020 all=21385 active=1069 piece=▁halaman
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=5040 all=21377 active=1061 piece=▁subject
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=5060 all=21361 active=1045 piece=▁borrowed
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=5080 all=21344 active=1028 piece=▁whatever
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=5100 all=21332 active=1016 piece=▁berbelanja
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=7 min_freq=5
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=7 size=5120 all=21315 active=1050 piece=▁understands
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=5140 all=21365 active=1100 piece=uct
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=5160 all=21415 active=1150 piece=buru
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=5180 all=21450 active=1185 piece=uasa
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=5200 all=21476 active=1211 piece=▁SMA
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=6 min_freq=5
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=5220 all=21492 active=1090 piece=▁odd
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=5240 all=21521 active=1119 piece=atnya
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=5260 all=21562 active=1160 piece=kipun
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=5280 all=21574 active=1172 piece=▁Pend
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=5300 all=21582 active=1180 piece=▁izin
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=6 min_freq=4
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=5320 all=21579 active=1074 piece=▁sapi
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=5340 all=21596 active=1091 piece=isfied
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=5360 all=21592 active=1087 piece=▁Their
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=5380 all=21579 active=1074 piece=▁means
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=5400 all=21565 active=1060 piece=▁telat
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=6 min_freq=4
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=5420 all=21566 active=1080 piece=ounting
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=5440 all=21559 active=1073 piece=▁burned
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=5460 all=21545 active=1059 piece=▁kembar
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=5480 all=21546 active=1060 piece=▁sempit
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=5500 all=21535 active=1049 piece=▁Pacific
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=6 min_freq=4
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=5520 all=21520 active=1062 piece=▁concert
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=5540 all=21507 active=1049 piece=▁menjaga
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=5560 all=21494 active=1036 piece=▁Dilarang
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=5580 all=21476 active=1018 piece=▁mendidih
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=5600 all=21462 active=1004 piece=▁Bangunlah
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=6 min_freq=4
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=5620 all=21448 active=1060 piece=▁menghemat
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=6 size=5640 all=21431 active=1043 piece=▁understood
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=5660 all=21434 active=1046 piece=ji
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=5680 all=21479 active=1091 piece=itz
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=5700 all=21518 active=1130 piece=▁Ed
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=5 min_freq=4
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=5720 all=21544 active=1100 piece=eren
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=5740 all=21576 active=1132 piece=uary
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=5760 all=21589 active=1145 piece=▁Piz
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=5780 all=21610 active=1166 piece=▁sir
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=5800 all=21639 active=1195 piece=enjak
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=5 min_freq=4
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=5820 all=21662 active=1104 piece=murid
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=5840 all=21671 active=1113 piece=▁Menc
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=5860 all=21670 active=1112 piece=▁deal
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=5880 all=21672 active=1114 piece=▁jump
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=5900 all=21677 active=1119 piece=▁sale
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=5 min_freq=4
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=5920 all=21675 active=1082 piece=abaran
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=5940 all=21688 active=1095 piece=stairs
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=5960 all=21681 active=1088 piece=▁Tekan
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=5980 all=21671 active=1078 piece=▁kapal
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=6000 all=21668 active=1075 piece=▁saved
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=5 min_freq=4
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=6020 all=21651 active=1067 piece=abaikan
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=6040 all=21646 active=1062 piece=▁Pulpen
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=6060 all=21634 active=1050 piece=▁diperb
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=6080 all=21623 active=1039 piece=▁lubang
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=6100 all=21621 active=1037 piece=▁selain
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=5 min_freq=4
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=6120 all=21607 active=1068 piece=▁Namanya
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=6140 all=21591 active=1052 piece=▁disebut
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=6160 all=21579 active=1040 piece=▁menebak
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=6180 all=21565 active=1026 piece=▁tourist
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=6200 all=21552 active=1013 piece=▁diundang
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=5 min_freq=4
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=6220 all=21539 active=1065 piece=▁perlahan
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=6240 all=21522 active=1048 piece=▁terbunuh
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=6260 all=21503 active=1029 piece=▁following
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=6280 all=21487 active=1013 piece=▁tenggelam
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=6300 all=21471 active=997 piece=▁menghubung
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=5 min_freq=4
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=5 size=6320 all=21461 active=1061 piece=▁mengirimkan
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6340 all=21443 active=1043 piece=fl
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6360 all=21471 active=1071 piece=ded
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6380 all=21507 active=1107 piece=ols
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6400 all=21540 active=1140 piece=zat
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=4 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6420 all=21550 active=1087 piece=akmu
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6440 all=21579 active=1116 piece=erve
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6460 all=21602 active=1139 piece=okan
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6480 all=21623 active=1160 piece=zine
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6500 all=21631 active=1168 piece=▁Rok
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=4 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6520 all=21650 active=1099 piece=▁kek
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6540 all=21669 active=1118 piece=▁tuk
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6560 all=21697 active=1146 piece=aving
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6580 all=21717 active=1166 piece=ilkan
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6600 all=21746 active=1195 piece=oured
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=4 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6620 all=21767 active=1108 piece=▁Bila
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6640 all=21759 active=1100 piece=▁Math
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6660 all=21755 active=1096 piece=▁dece
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6680 all=21748 active=1089 piece=▁nark
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6700 all=21750 active=1091 piece=▁repl
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=4 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6720 all=21746 active=1082 piece=andung
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6740 all=21768 active=1104 piece=irikan
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6760 all=21783 active=1119 piece=▁Cinta
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6780 all=21770 active=1106 piece=▁Santa
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6800 all=21759 active=1095 piece=▁bocor
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=4 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6820 all=21746 active=1075 piece=▁fiksi
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6840 all=21736 active=1065 piece=▁lebah
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6860 all=21727 active=1056 piece=▁putus
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6880 all=21724 active=1053 piece=▁tools
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6900 all=21740 active=1069 piece=loading
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=4 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6920 all=21731 active=1077 piece=▁Sangat
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6940 all=21722 active=1068 piece=▁dibawa
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6960 all=21710 active=1056 piece=▁intend
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=6980 all=21706 active=1052 piece=▁partic
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=7000 all=21699 active=1045 piece=▁solusi
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=4 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=7020 all=21697 active=1083 piece=umpulkan
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=7040 all=21683 active=1069 piece=▁anxious
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=7060 all=21666 active=1052 piece=▁forsake
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=7080 all=21651 active=1037 piece=▁lasagna
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=7100 all=21636 active=1022 piece=▁pretend
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=4 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=7120 all=21620 active=1065 piece=▁tahunmu
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=7140 all=21609 active=1054 piece=▁Harusnya
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=7160 all=21592 active=1037 piece=▁believes
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=7180 all=21573 active=1018 piece=▁hesitate
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=7200 all=21559 active=1004 piece=▁murdered
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=4 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=7220 all=21541 active=1060 piece=▁tanganku
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=7240 all=21521 active=1040 piece=▁convinced
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=7260 all=21505 active=1024 piece=▁membangun
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=7280 all=21493 active=1012 piece=▁pertolong
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=7300 all=21479 active=998 piece=▁aggressive
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=4 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=7320 all=21462 active=1057 piece=▁menyalakan
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=7340 all=21442 active=1037 piece=▁meneleponmu
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=4 size=7360 all=21422 active=1017 piece=▁mengendalikan
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3 size=7380 all=21440 active=1035 piece=arb
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3 size=7400 all=21482 active=1077 piece=lim
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=3 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3 size=7420 all=21523 active=1114 piece=sed
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3 size=7440 all=21543 active=1134 piece=▁Gu
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3 size=7460 all=21559 active=1150 piece=ahal
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3 size=7480 all=21582 active=1173 piece=ebar
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3 size=7500 all=21606 active=1197 piece=ilin
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=3 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3 size=7520 all=21628 active=1100 piece=osis
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3 size=7540 all=21647 active=1119 piece=vent
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3 size=7560 all=21657 active=1129 piece=▁Sed
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3 size=7580 all=21660 active=1132 piece=▁hom
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3 size=7600 all=21675 active=1147 piece=▁rob
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=3 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3 size=7620 all=21693 active=1100 piece=▁vom
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3 size=7640 all=21718 active=1125 piece=cript
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3 size=7660 all=21728 active=1135 piece=irely
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3 size=7680 all=21741 active=1148 piece=uling
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3 size=7700 all=21757 active=1164 piece=▁Cook
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=3 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3 size=7720 all=21772 active=1102 piece=▁Each
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3 size=7740 all=21762 active=1092 piece=▁Perc
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3 size=7760 all=21753 active=1083 piece=▁beef
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3 size=7780 all=21754 active=1084 piece=▁hoax
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3 size=7800 all=21748 active=1078 piece=▁ours
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=3 min_freq=3
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3 size=7820 all=21753 active=1093 piece=▁rare
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3 size=7840 all=21754 active=1094 piece=▁ular
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3 size=7860 all=21749 active=1089 piece=amaian
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3 size=7880 all=21766 active=1106 piece=hatian
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3 size=7900 all=21776 active=1116 piece=onomic
# bpe_model_trainer.cc(159) LOG(INFO) Updating active symbols. max_freq=3 min_freq=2
# bpe_model_trainer.cc(268) LOG(INFO) Added: freq=3 size=7920 all=21778 active=1090 piece=▁Gener
# trainer_interface.cc(687) LOG(INFO) Saving model: spm_bpe.model
# trainer_interface.cc(699) LOG(INFO) Saving vocabs: spm_bpe.vocab

# %% [markdown]
# ### C. Pembagian Data
# Gunakan sklearn untuk membagi data menjadi set pelatihan, validasi, dan pengujian. Rasio yang umum digunakan adalah 80-10-10.

# %%
from sklearn.model_selection import train_test_split

train_df, test_df = train_test_split(df, test_size=0.2, random_state=42)
val_df, test_df = train_test_split(test_df, test_size=0.5, random_state=42)

print(f"Ukuran data train: {len(train_df)}")
print(f"Ukuran data validation: {len(val_df)}")
print(f"Ukuran data test: {len(test_df)}")
# Out:
# Ukuran data train: 11904
# Ukuran data validation: 1488
# Ukuran data test: 1489

# %% [markdown]
# ## 3. Implementasi Model (Baseline: RNN + Attention)
# ### A. Konsep Dasar
# Arsitektur ini terdiri dari dua bagian: Encoder (untuk memahami kalimat sumber) dan Decoder (untuk menghasilkan kalimat target). Attention Mechanism memungkinkan decoder untuk "melihat" bagian-bagian yang relevan dari kalimat sumber saat menghasilkan setiap token target, mengatasi masalah bottleneck pada RNN standar.
#
# ### B. Implementasi di PyTorch
# Anda akan membuat kelas EncoderRNN, DecoderRNN, dan Seq2Seq (model utama).

# %%
import torch
import torch.nn as nn
from torch import optim

# Contoh pseudo-code untuk arsitektur
# Encoder
class EncoderRNN(nn.Module):
    def __init__(self, input_size, hidden_size):
        super(EncoderRNN, self).__init__()
        self.hidden_size = hidden_size
        self.embedding = nn.Embedding(input_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size) # Atau LSTM

    def forward(self, input, hidden):
        # ... (implementasi forward pass)
        pass

# Decoder dengan Attention
class AttnDecoderRNN(nn.Module):
    def __init__(self, hidden_size, output_size, dropout_p=0.1, max_length=50):
        super(AttnDecoderRNN, self).__init__()
        # ... (implementasi __init__ dan forward pass)
        pass

# Model gabungan
class Seq2Seq(nn.Module):
    def __init__(self, encoder, decoder, device):
        super().__init__()
        # ... (implementasi __init__ dan forward pass)
        pass

# %% [markdown]
# ## 4. Implementasi Model (Transformer)
# ### A. Konsep Dasar
# Transformer adalah arsitektur yang sepenuhnya berbasis Attention (Self-Attention). Ia tidak menggunakan RNN. Ini memungkinkan pemrosesan paralel yang lebih cepat dan efektif dalam menangkap dependensi jarak jauh.
#
# ### B. Implementasi di PyTorch
# Anda akan membuat blok-blok pembangun Transformer: Multi-Head Attention, Feed-Forward Network, dan kemudian menggabungkannya ke dalam Encoder dan Decoder.

# %%
import torch
import torch.nn as nn
import math

# Contoh pseudo-code untuk arsitektur
class MultiHeadAttention(nn.Module):
    def __init__(self, d_model, n_heads, dropout):
        super(MultiHeadAttention, self).__init__()
        self.attn = nn.MultiheadAttention(d_model, n_heads, dropout=dropout, batch_first=True)

    def forward(self, query, key, value, attn_mask=None):
        out, _ = self.attn(query, key, value, attn_mask=attn_mask)
        return out


class PositionwiseFeedForward(nn.Module):
    def __init__(self, d_model, d_ff, dropout):
        super(PositionwiseFeedForward, self).__init__()
        self.linear1 = nn.Linear(d_model, d_ff)
        self.linear2 = nn.Linear(d_ff, d_model)
        self.dropout = nn.Dropout(dropout)
        self.relu = nn.ReLU()

    def forward(self, x):
        return self.linear2(self.dropout(self.relu(self.linear1(x))))


class PositionalEncoding(nn.Module):
    def __init__(self, d_model, dropout, max_len=5000):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(p=dropout)

        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0)  # (1, max_len, d_model)
        self.register_buffer('pe', pe)

    def forward(self, x):
        x = x + self.pe[:, :x.size(1), :]
        return self.dropout(x)


class EncoderLayer(nn.Module):
    def __init__(self, d_model, n_heads, d_ff, dropout): 
        super().__init__()
        self.attn = MultiHeadAttention(d_model, n_heads, dropout)
        self.ffn = PositionwiseFeedForward(d_model, d_ff, dropout)
        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)
        self.dropout = nn.Dropout(dropout)

    def forward(self, src):
        attn_out = self.attn(src, src, src)
        src = self.norm1(src + self.dropout(attn_out))
        ffn_out = self.ffn(src)
        src = self.norm2(src + self.dropout(ffn_out))
        return src


class Encoder(nn.Module):
    def __init__(self, input_dim, d_model, n_heads, d_ff, device, dropout):
        super().__init__()
        self.device = device
        self.embed = nn.Embedding(input_dim, d_model)
        self.pos_enc = PositionalEncoding(d_model, dropout)
        self.layer = EncoderLayer(d_model, n_heads, d_ff, dropout)

    def forward(self, src):
        src = self.embed(src)
        src = self.pos_enc(src)
        return self.layer(src)


class DecoderLayer(nn.Module):
    def __init__(self, d_model, n_heads, d_ff, dropout):
        super().__init__()
        self.self_attn = MultiHeadAttention(d_model, n_heads, dropout)
        self.cross_attn = MultiHeadAttention(d_model, n_heads, dropout)
        self.ffn = PositionwiseFeedForward(d_model, d_ff, dropout)
        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)
        self.norm3 = nn.LayerNorm(d_model)
        self.dropout = nn.Dropout(dropout)

    def forward(self, trg, enc_out):
        trg2 = self.self_attn(trg, trg, trg)
        trg = self.norm1(trg + self.dropout(trg2))
        trg2 = self.cross_attn(trg, enc_out, enc_out)
        trg = self.norm2(trg + self.dropout(trg2))
        ffn_out = self.ffn(trg)
        trg = self.norm3(trg + self.dropout(ffn_out))
        return trg


class Decoder(nn.Module):
    def __init__(self, output_dim, d_model, n_heads, d_ff, device, dropout):
        super().__init__()
        self.device = device
        self.embed = nn.Embedding(output_dim, d_model)
        self.pos_enc = PositionalEncoding(d_model, dropout)
        self.layer = DecoderLayer(d_model, n_heads, d_ff, dropout)
        self.fc_out = nn.Linear(d_model, output_dim)

    def forward(self, trg, enc_out):
        trg = self.embed(trg)
        trg = self.pos_enc(trg)
        dec_out = self.layer(trg, enc_out)
        output = self.fc_out(dec_out)
        return output


class Transformer(nn.Module):
    def __init__(self, encoder, decoder, src_pad_idx, trg_pad_idx, device):
        super(Transformer, self).__init__()
        self.encoder = encoder
        self.decoder = decoder
        self.src_pad_idx = src_pad_idx
        self.trg_pad_idx = trg_pad_idx
        self.device = device

    def forward(self, src, trg):
        enc_out = self.encoder(src)
        output = self.decoder(trg, enc_out)
        return output

# %% [markdown]
# ## 5. Evaluasi dan Analisis
# ### A. Metrik SacreBLEU
# SacreBLEU adalah metrik evaluasi standar untuk machine translation yang lebih andal daripada BLEU biasa karena menghindari tokenisasi yang tidak standar. Ia mengukur seberapa mirip terjemahan model Anda dengan terjemahan referensi.

# %%
# Contoh penggunaan SacreBLEU
from sacrebleu.metrics import BLEU, CHRF

# Terjemahan model Anda
hypotheses = ["the cat is on the mat"]
# Terjemahan referensi
references = [["a cat is on a mat"]]

bleu = BLEU()
score = bleu.corpus_score(hypotheses, references)
print(score.score)

# Untuk chrF
chrf = CHRF()
score_chrf = chrf.corpus_score(hypotheses, references)
print(score_chrf.score)
# Out:
# 32.46679154750991
# 50.36239285689067

# %% [markdown]
# ## 6. Ablation Study
# ### A. Ukuran Vocab
# Uji coba ini membandingkan performa model dengan ukuran vocab yang berbeda. Kamu perlu melatih dua model secara terpisah: satu dengan vocab_size=4000 dan satu lagi dengan vocab_size=8000.

# %%
import sentencepiece as spm

# Latih model dengan vocab size 4000
spm.SentencePieceTrainer.train(
    '--input=/kaggle/working/corpus.txt --model_prefix=spm_bpe_4000 --vocab_size=4000 --model_type=bpe')

print("Model SentencePiece dengan vocab 4000 berhasil dilatih dan disimpan.")

# Latih model dengan vocab size 8000
# Gunakan nama file yang berbeda untuk membedakan
spm.SentencePieceTrainer.train(
    '--input=/kaggle/working/corpus.txt --model_prefix=spm_bpe_8000 --vocab_size=8000 --model_type=bpe')

print("Model SentencePiece dengan vocab 8000 berhasil dilatih dan disimpan.")
# Out:
# Model SentencePiece dengan vocab 4000 berhasil dilatih dan disimpan.
# Model SentencePiece dengan vocab 8000 berhasil dilatih dan disimpan.

# %% [markdown]
# ### B. Ablation Study: Dropout
# Untuk uji coba ini, kamu bisa menggunakan salah satu model dari eksperimen vocab (misalnya, model dengan vocab 8000).

# %%
import torch
import torch.nn as nn
from torch import optim
from torch.utils.data import DataLoader
import sacrebleu

# Asumsikan Anda sudah memiliki data loader dan fungsi pelatihan (train_model, translate_sentences)
# train_loader = ...
# test_data = ...
# sp_tokenizer = ...
# references_test = ...

# Parameter model umum
d_model = 512
n_heads = 8
d_ff = 2048
src_vocab_size = 8000 # Gunakan ukuran vocab terbaik dari uji coba sebelumnya
trg_vocab_size = 8000
src_pad_idx = 0
trg_pad_idx = 0
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# --- Uji Coba Model dengan Dropout 0.1 ---
print("Memulai pelatihan untuk model dengan dropout 0.1")
encoder_d01 = Encoder(src_vocab_size, d_model, n_heads, d_ff, device, dropout=0.1)
decoder_d01 = Decoder(trg_vocab_size, d_model, n_heads, d_ff, device, dropout=0.1)
model_dropout_01 = Transformer(encoder_d01, decoder_d01, src_pad_idx, trg_pad_idx, device).to(device)

# Latih model ini (Ganti dengan kode pelatihan Anda)
# train_model(model_dropout_01, train_loader, ...)
torch.save(model_dropout_01.state_dict(), 'transformer_dropout_01.pth')

# Evaluasi model
# hypotheses_d01 = translate_sentences(model_dropout_01, test_data, sp_tokenizer)
# bleu_score_d01 = sacrebleu.corpus_bleu(hypotheses_d01, [references_test]).score
# print(f"Hasil Dropout 0.1: BLEU={bleu_score_d01:.2f}")

# --- Uji Coba Model dengan Dropout 0.5 ---
print("\nMemulai pelatihan untuk model dengan dropout 0.5")
encoder_d05 = Encoder(src_vocab_size, d_model, n_heads, d_ff, device, dropout=0.5)
decoder_d05 = Decoder(trg_vocab_size, d_model, n_heads, d_ff, device, dropout=0.5)
model_dropout_05 = Transformer(encoder_d05, decoder_d05, src_pad_idx, trg_pad_idx, device).to(device)

# Latih model ini (Ganti dengan kode pelatihan Anda)
# train_model(model_dropout_05, train_loader, ...)
torch.save(model_dropout_05.state_dict(), 'transformer_dropout_05.pth')

# Evaluasi model
# hypotheses_d05 = translate_sentences(model_dropout_05, test_data, sp_tokenizer)
# bleu_score_d05 = sacrebleu.corpus_bleu(hypotheses_d05, [references_test]).score
# print(f"Hasil Dropout 0.5: BLEU={bleu_score_d05:.2f}")
# Out:
# Memulai pelatihan untuk model dengan dropout 0.1
#
# Memulai pelatihan untuk model dengan dropout 0.5

# %% [markdown]
# ### C. Ablation Study: Beam Search Size
#
# Ini adalah uji coba paling mudah karena tidak memerlukan pelatihan model baru. Cukup gunakan model Transformer terbaik yang sudah kamu latih.

# %%
import torch
import sacrebleu
import pandas as pd
import sentencepiece as spm

# ---- MODEL SETUP (sudah ada di code kamu) ----
model_path = '/kaggle/working/transformer_dropout_05.pth' 
d_model = 512
n_heads = 8
d_ff = 2048
src_vocab_size = 8000
trg_vocab_size = 8000
src_pad_idx = 0
trg_pad_idx = 0
device = 'cuda' if torch.cuda.is_available() else 'cpu'

encoder = Encoder(src_vocab_size, d_model, n_heads, d_ff, device, dropout=0.1)
decoder = Decoder(trg_vocab_size, d_model, n_heads, d_ff, device, dropout=0.1)
best_model = Transformer(encoder, decoder, src_pad_idx, trg_pad_idx, device).to(device)
best_model.load_state_dict(torch.load(model_path, map_location=device))
best_model.eval()

sp_tokenizer = spm.SentencePieceProcessor(model_file='spm_bpe_8000.model')


# ---- TRANSLATE FUNCTION ----
def translate_with_beam_search(model, test_data, tokenizer, beam_size=1, max_len=50):
    model.eval()
    hypotheses = []

    for sentence in test_data:
        # Encode input
        src_tokens = tokenizer.encode(sentence)
        src_tensor = torch.LongTensor(src_tokens).unsqueeze(0).to(device)  # [1, src_len]

        # Start with <s> token (anggap id 1 = <s>, id 2 = </s>)
        ys = torch.LongTensor([[1]]).to(device)  

        for i in range(max_len):
            # forward pass
            out = model(src_tensor, ys)
            prob = out[:, -1, :]  # token terakhir
            next_word = prob.argmax(dim=-1).item()

            ys = torch.cat([ys, torch.LongTensor([[next_word]]).to(device)], dim=1)

            if next_word == 2:  # </s> token
                break

        # Decode hasil jadi string
        hyp = tokenizer.decode(ys.squeeze().tolist())
        hypotheses.append(hyp)

    return hypotheses


# ---- EVALUATION ----
# Asumsikan test_df sudah ada
# test_df = pd.read_csv("test.csv")

hypotheses_greedy = translate_with_beam_search(best_model, test_df['eng'].tolist(), sp_tokenizer, beam_size=1)
references = [test_df['id'].tolist()]

bleu_score_greedy = sacrebleu.corpus_bleu(hypotheses_greedy, references).score
print(f"Hasil Greedy Search (beam_size=1): BLEU={bleu_score_greedy:.2f}")
# Out:
# Hasil Greedy Search (beam_size=1): BLEU=0.00
